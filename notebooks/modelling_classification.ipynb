# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

import joblib
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from utilities import utils
VECTORIZER_PATH = utils.get_datapath('vectorizer_data')
DATA_PATH = utils.get_datapath('data')
LEXVEC_PATH = utils.get_datapath('lexVec_data')

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # **Spotify Popularity Classification**

# %% [markdown]
# # Logistic Regression With N-grams = 1

# %%
from sklearn.linear_model import LogisticRegression

# %%
X_train, X_val, X_test, y_train, y_val, y_test = utils.load_transformed_data('bag_of_words_three_class')

# %%
c_range = [
    (1/10)**n
    for n in np.arange(0,10,1)
]

train_accuracy = []
valid_accuracy = []

for c in c_range:
    log_reg = LogisticRegression(penalty='l2', C=c, solver='newton-cholesky')
    log_reg.fit(X_train, y_train)
    train_accuracy.append(log_reg.score(X_train, y_train))
    valid_accuracy.append(log_reg.score(X_val, y_val))

# %%
plt.figure()
plt.title('Effect on Model Accuracy by Varying C')
plt.plot(c_range, train_accuracy, label='Train')
plt.plot(c_range, valid_accuracy, label='Validation')
plt.xscale('log')
plt.xlabel('log(C)')
plt.ylabel('Accuracy')
plt.axvline(x=c_range[np.argmax(valid_accuracy)], c='red', linestyle='--')
plt.ylim(0.2,1)
plt.legend()
plt.show()


print(f'Max Accuracy Validation: {valid_accuracy[np.argmax(valid_accuracy)]}')
print(f'C: {c_range[np.argmax(valid_accuracy)]}')

print(f'Accuracy of Train: {train_accuracy[np.argmax(train_accuracy)]}')
# Out:
# Max Accuracy Validation: 0.4301543332014246
# C: 0.0010000000000000002
# Accuracy of Train: 0.5470254583827991

# %%
log_reg = LogisticRegression(
    penalty='l2', C=c_range[np.argmax(valid_accuracy)], solver='newton-cholesky'
    )
log_reg.fit(X_train, y_train)

print(f'Test Accuracy: {log_reg.score(X_test, y_test)}')
# Out:
# Test Accuracy: 0.4272523413797652

# %% [markdown]
# # Logistic Regression With N-grams = 1 and 2

# %%
X_train, X_val, X_test, y_train, y_val, y_test = utils.load_transformed_data('2_grams_three_class')

# %%
c_range = [
    (1/10)**n
    for n in np.arange(0,10,1)
]

train_accuracy = []
valid_accuracy = []

for c in c_range:
    log_reg = LogisticRegression(penalty='l2', C=c, solver='newton-cholesky')
    log_reg.fit(X_train, y_train)
    train_accuracy.append(log_reg.score(X_train, y_train))
    valid_accuracy.append(log_reg.score(X_val, y_val))

# %%
plt.figure()
plt.title('Effect on Model Accuracy by Varying C')
plt.plot(c_range, train_accuracy, label='Train')
plt.plot(c_range, valid_accuracy, label='Validation')
plt.xscale('log')
plt.xlabel('log(C)')
plt.ylabel('Accuracy')
plt.axvline(x=c_range[np.argmax(valid_accuracy)], c='red', linestyle='--')
plt.ylim(0.2,1)
plt.legend()
plt.show()


print(f'Max Accuracy Validation: {valid_accuracy[np.argmax(valid_accuracy)]}')
print(f'C: {c_range[np.argmax(valid_accuracy)]}')

print(f'Accuracy of Train: {train_accuracy[np.argmax(train_accuracy)]}')
# Out:
# Max Accuracy Validation: 0.4437409312755573
# C: 0.0010000000000000002
# Accuracy of Train: 0.5630743525480367

# %%
log_reg = LogisticRegression(
    penalty='l2', C=c_range[np.argmax(valid_accuracy)], solver='newton-cholesky'
    )
log_reg.fit(X_train, y_train)

print(f'Test Accuracy: {log_reg.score(X_test, y_test)}')
# Out:
# Test Accuracy: 0.41590819153146025

# %% [markdown]
# # Logistic Regression With N-grams = 1, 2 and 3

# %%
X_train, X_val, X_test, y_train, y_val, y_test = utils.load_transformed_data('3_grams_three_class')

# %%
c_range = [
    (1/10)**n
    for n in np.arange(0,10,1)
]

train_accuracy = []
valid_accuracy = []

for c in c_range:
    log_reg = LogisticRegression(penalty='l2', C=c, solver='newton-cholesky')
    log_reg.fit(X_train, y_train)
    train_accuracy.append(log_reg.score(X_train, y_train))
    valid_accuracy.append(log_reg.score(X_val, y_val))

# %%
plt.figure()
plt.title('Effect on Model Accuracy by Varying C')
plt.plot(c_range, train_accuracy, label='Train')
plt.plot(c_range, valid_accuracy, label='Validation')
plt.xscale('log')
plt.xlabel('log(C)')
plt.ylabel('Accuracy')
plt.axvline(x=c_range[np.argmax(valid_accuracy)], c='red', linestyle='--')
plt.ylim(0.2,1)
plt.legend()
plt.show()


print(f'Max Accuracy Validation: {valid_accuracy[np.argmax(valid_accuracy)]}')
print(f'C: {c_range[np.argmax(valid_accuracy)]}')

print(f'Accuracy of Train: {train_accuracy[np.argmax(train_accuracy)]}')
# Out:
# Max Accuracy Validation: 0.4362221342830761
# C: 0.00010000000000000002
# Accuracy of Train: 0.5636459569977575

# %%
log_reg = LogisticRegression(
    penalty='l2', C=c_range[np.argmax(valid_accuracy)], solver='newton-cholesky'
    )
log_reg.fit(X_train, y_train)

print(f'Test Accuracy: {log_reg.score(X_test, y_test)}')
# Out:
# Test Accuracy: 0.4325286901464187

# %% [markdown]
# # Logistic Regression With TF-IDF

# %%
X_train, X_val, X_test, y_train, y_val, y_test = utils.load_transformed_data('tf_idf_three_class')

# %%
c_range = [
    (1/10)**n
    for n in np.arange(0,10,1)
]

train_accuracy = []
valid_accuracy = []

for c in c_range:
    log_reg = LogisticRegression(penalty='l2', C=c, solver='newton-cholesky')
    log_reg.fit(X_train, y_train)
    train_accuracy.append(log_reg.score(X_train, y_train))
    valid_accuracy.append(log_reg.score(X_val, y_val))

# %%
plt.figure()
plt.title('Effect on Model Accuracy by Varying C')
plt.plot(c_range, train_accuracy, label='Train')
plt.plot(c_range, valid_accuracy, label='Validation')
plt.xscale('log')
plt.xlabel('log(C)')
plt.ylabel('Accuracy')
plt.axvline(x=c_range[np.argmax(valid_accuracy)], c='red', linestyle='--')
plt.ylim(0.2,1)
plt.legend()
plt.show()


print(f'Max Accuracy Validation: {valid_accuracy[np.argmax(valid_accuracy)]}')
print(f'C: {c_range[np.argmax(valid_accuracy)]}')

print(f'Accuracy of Train: {train_accuracy[np.argmax(train_accuracy)]}')
# Out:
# Max Accuracy Validation: 0.43609022556390975
# C: 0.1
# Accuracy of Train: 0.5373081827375457

# %%
log_reg = LogisticRegression(
    penalty='l2', C=c_range[np.argmax(valid_accuracy)], solver='newton-cholesky'
    )
log_reg.fit(X_train, y_train)

print(f'Test Accuracy: {log_reg.score(X_test, y_test)}')
# Out:
# Test Accuracy: 0.43173723783142065

# %% [markdown]
# # Logistic Regression with all vectorizers combined

# %%
X_train, X_val, X_test, y_train, y_val, y_test = utils.load_transformed_data('all_vectorizers_three_class')

# %%
c_range = [
    (1/10)**n
    for n in np.arange(0,10,1)
]

train_accuracy = []
valid_accuracy = []

for c in c_range:
    log_reg = LogisticRegression(penalty='l2', C=c, solver='newton-cholesky')
    log_reg.fit(X_train, y_train)
    train_accuracy.append(log_reg.score(X_train, y_train))
    valid_accuracy.append(log_reg.score(X_val, y_val))

# %%
plt.figure()
plt.title('Effect on Model Accuracy by Varying C')
plt.plot(c_range, train_accuracy, label='Train')
plt.plot(c_range, valid_accuracy, label='Validation')
plt.xscale('log')
plt.xlabel('log(C)')
plt.ylabel('Accuracy')
plt.axvline(x=c_range[np.argmax(valid_accuracy)], c='red', linestyle='--')
plt.ylim(0.2,1)
plt.legend()
plt.show()


print(f'Max Accuracy Validation: {valid_accuracy[np.argmax(valid_accuracy)]}')
print(f'C: {c_range[np.argmax(valid_accuracy)]}')

print(f'Accuracy of Train: {train_accuracy[np.argmax(train_accuracy)]}')
# Out:
# Max Accuracy Validation: 0.42949478960559295
# C: 0.00010000000000000002
# Accuracy of Train: 0.6013718506793299

# %%
log_reg = LogisticRegression(
    penalty='l2', C=c_range[np.argmax(valid_accuracy)], solver='newton-cholesky'
    )

log_reg.fit(X_train, y_train)

print(f'Test Accuracy: {log_reg.score(X_test, y_test)}')
# Out:
# Test Accuracy: 0.43213296398891965

# %% [markdown]
# # Random Forest for Classification n-grams = 1, 2 and 3

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_val, X_test, y_train, y_val, y_test = utils.load_transformed_data('3_grams_three_class')

# %%
max_depth_range = np.arange(1,11,1)

train_accuracy = []
valid_accuracy = []

for max_depth in max_depth_range:
    random_forest = RandomForestClassifier(
        n_estimators=1000,
        max_depth = max_depth,
        n_jobs = -1,
        criterion='entropy',
        max_features='log2'
    )

    random_forest.fit(X_train, y_train)

    train_accuracy.append(random_forest.score(X_train, y_train))
    valid_accuracy.append(random_forest.score(X_val, y_val))

# %%
plt.figure()
plt.title('Effect on Model Accuracy by Varying Max Depth')
plt.plot(max_depth_range, train_accuracy, label='Train')
plt.plot(max_depth_range, valid_accuracy, label='Validation')
plt.xlabel('Max Depth')
plt.ylabel('Accuracy')
plt.axvline(x=max_depth_range[np.argmax(valid_accuracy)], c='red', linestyle='--')
plt.ylim(0.2,1)
plt.legend()
plt.show()


print(f'Max Accuracy Validation: {valid_accuracy[np.argmax(valid_accuracy)]}')
print(f'Max Depth: {max_depth_range[np.argmax(valid_accuracy)]}')

print(f'Accuracy of Train: {train_accuracy[np.argmax(train_accuracy)]}')
# Out:
# Max Accuracy Validation: 0.43635404300224245
# Max Depth: 10
# Accuracy of Train: 0.6109572176054171

# %%
pd.DataFrame(
    {
        'Max Depth': max_depth_range,
        'Validation Accuracy': valid_accuracy,
        'Train Accuracy': train_accuracy
    }
).sort_values(by='Validation Accuracy', ascending=False)
# Out:
#    Max Depth  Validation Accuracy  Train Accuracy
# 9         10             0.436354        0.610957
# 7          8             0.433056        0.545794
# 8          9             0.431869        0.576441
# 6          7             0.429495        0.515675
# 5          6             0.428044        0.486655
# 4          5             0.419338        0.458779
# 3          4             0.407202        0.435870
# 2          3             0.392165        0.409796
# 1          2             0.370004        0.377611
# 0          1             0.340588        0.341819

# %% [markdown]
# # Loading LexVec Lyric Embeddings

# %%
from sklearn.model_selection import train_test_split
import joblib

# %%
with open(LEXVEC_PATH / 'lexVec.pkl', 'rb') as f:
    X = joblib.load(f)

# %%
df = pd.read_csv(DATA_PATH / 'clean_lyrics.csv')

# %%
y = df.popularity_rating

# %%
X_remainder, X_test, y_remainder, y_test = train_test_split(X, y, test_size=0.2, random_state=33, stratify=y)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_remainder, y_remainder, test_size=0.25, random_state=33, stratify=y_remainder)

# %%
print(f'\nX\nTrain Shape: {X_train.shape} \
\nValid Shape: {X_val.shape} \
\nTest Shape: {X_test.shape} \
\ny\nTrain Shape: {y_train.shape} \
\nValid Shape: {y_val.shape} \
\nTest Shape: {y_test.shape}')
# Out:
# X
# Train Shape: (22743, 300)
# Valid Shape: (7581, 300)
# Test Shape: (7581, 300)
# y
# Train Shape: (22743,)
# Valid Shape: (7581,)
# Test Shape: (7581,)

# %% [markdown]
# # Logisitic Regression with LexVec Lyric Embeddings

# %%
c_range = [
    (1/10)**n
    for n in np.arange(0,10,1)
]

train_accuracy = []
valid_accuracy = []

for c in c_range:
    log_reg = LogisticRegression(penalty='l2', C=c, solver='newton-cholesky')
    log_reg.fit(X_train, y_train)
    train_accuracy.append(log_reg.score(X_train, y_train))
    valid_accuracy.append(log_reg.score(X_val, y_val))

# %%
plt.figure()
plt.title('Effect on Model Accuracy by Varying C')
plt.plot(c_range, train_accuracy, label='Train')
plt.plot(c_range, valid_accuracy, label='Validation')
plt.xscale('log')
plt.xlabel('log(C)')
plt.ylabel('Accuracy')
plt.axvline(x=c_range[np.argmax(valid_accuracy)], c='red', linestyle='--')
plt.ylim(0.2,1)
plt.legend()
plt.show()


print(f'Max Accuracy Validation: {valid_accuracy[np.argmax(valid_accuracy)]}')
print(f'C: {c_range[np.argmax(valid_accuracy)]}')

print(f'Accuracy of Train: {train_accuracy[np.argmax(train_accuracy)]}')
# Out:
# Max Accuracy Validation: 0.38939453897902654
# C: 1.0
# Accuracy of Train: 0.3961218836565097

# %%
log_reg = LogisticRegression(
    penalty='l2', C=c_range[np.argmax(valid_accuracy)], solver='newton-cholesky'
    )
log_reg.fit(X_train, y_train)

print(f'Test Accuracy: {log_reg.score(X_test, y_test)}')
# Out:
# Test Accuracy: 0.3900540825748582

# %% [markdown]
# ## Random Forest and LexVec Embedding

# %%
max_depth_range = np.arange(1,11,1)

train_accuracy = []
valid_accuracy = []

for max_depth in max_depth_range:
    random_forest = RandomForestClassifier(
        n_estimators=1000,
        max_depth = max_depth,
        n_jobs = -1,
        criterion='entropy',
        max_features='log2'
    )

    random_forest.fit(X_train, y_train)

    train_accuracy.append(random_forest.score(X_train, y_train))
    valid_accuracy.append(random_forest.score(X_val, y_val))

# %%
plt.figure()
plt.title('Effect on Model Accuracy by Varying Max Depth')
plt.plot(max_depth_range, train_accuracy, label='Train')
plt.plot(max_depth_range, valid_accuracy, label='Validation')
plt.xlabel('Max Depth')
plt.ylabel('Accuracy')
plt.axvline(x=max_depth_range[np.argmax(valid_accuracy)], c='red', linestyle='--')
plt.ylim(0.2,1)
plt.legend()
plt.show()


print(f'Max Accuracy Validation: {valid_accuracy[np.argmax(valid_accuracy)]}')
print(f'Max Depth: {max_depth_range[np.argmax(valid_accuracy)]}')

print(f'Accuracy of Train: {train_accuracy[np.argmax(train_accuracy)]}')
# Out:
# Max Accuracy Validation: 0.39308798311568394
# Max Depth: 9
# Accuracy of Train: 0.6772193641999736

# %% [markdown]
# ## LexVec and Popularity Separated by Standard Deviation

# %%
with open(LEXVEC_PATH / 'lexVec.pkl', 'rb') as f:
    X = joblib.load(f)

# %%
df = pd.read_csv(DATA_PATH / 'clean_lyrics.csv')

# %%
y = df.popularity_std

# %%
y.value_counts(normalize=True)
# Out:
# 1    0.662815
# 0    0.171270
# 2    0.165915
# Name: popularity_std, dtype: float64

# %%
X_remainder, X_test, y_remainder, y_test = train_test_split(X, y, test_size=0.2, random_state=33, stratify=y)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_remainder, y_remainder, test_size=0.25, random_state=33, stratify=y_remainder)

# %%
c_range = [
    (1/10)**n
    for n in np.arange(0,10,1)
]

train_accuracy = []
valid_accuracy = []

for c in c_range:
    log_reg = LogisticRegression(penalty='l2', C=c, solver='newton-cholesky')
    log_reg.fit(X_train, y_train)
    train_accuracy.append(log_reg.score(X_train, y_train))
    valid_accuracy.append(log_reg.score(X_val, y_val))

# %%
plt.figure()
plt.title('Effect on Model Accuracy by Varying C')
plt.plot(c_range, train_accuracy, label='Train')
plt.plot(c_range, valid_accuracy, label='Validation')
plt.xscale('log')
plt.xlabel('log(C)')
plt.ylabel('Accuracy')
plt.axvline(x=c_range[np.argmax(valid_accuracy)], c='red', linestyle='--')
plt.ylim(0.2,1)
plt.legend()
plt.show()


print(f'Max Accuracy Validation: {valid_accuracy[np.argmax(valid_accuracy)]}')
print(f'C: {c_range[np.argmax(valid_accuracy)]}')

print(f'Accuracy of Train: {train_accuracy[np.argmax(train_accuracy)]}')
# Out:
# Max Accuracy Validation: 0.6628413138108429
# C: 1.0
# Accuracy of Train: 0.6627973442377875

# %%
log_reg = LogisticRegression(
    penalty='l2', C=c_range[np.argmax(valid_accuracy)], solver='newton-cholesky'
    )
log_reg.fit(X_train, y_train)

print(f'Test Accuracy: {log_reg.score(X_test, y_test)}')
# Out:
# Test Accuracy: 0.6629732225300092

# %% [markdown]
# # Classifying NMF Components

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### N-grams = 1, 2 and 3

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import NMF

# %%
X_train, X_val, X_test, y_train, y_val, y_test = utils.load_transformed_data('bag_of_words_three_class')

# %%
c_range = [
    (1/10)**n
    for n in np.arange(0,10,1)
]

train_accuracy = []
valid_accuracy = []

for c in c_range:
    estimator = [
        ('reduce_dim', NMF(n_components=10)), 
        ('log_reg', LogisticRegression(penalty='l2', C=c, solver='newton-cholesky'))
    ]
    nmf_pipeline = Pipeline(estimator)

    nmf_pipeline.fit(X_train, y_train)
    train_accuracy.append(nmf_pipeline.score(X_train, y_train))
    valid_accuracy.append(nmf_pipeline.score(X_val, y_val))

# %%
plt.figure()
plt.title('Effect on Model Accuracy by Varying C')
plt.plot(c_range, train_accuracy, label='Train')
plt.plot(c_range, valid_accuracy, label='Validation')
plt.xscale('log')
plt.xlabel('log(C)')
plt.ylabel('Accuracy')
plt.axvline(x=c_range[np.argmax(valid_accuracy)], c='red', linestyle='--')
plt.ylim(0.2,1)
plt.legend()
plt.show()


print(f'Max Accuracy Validation: {valid_accuracy[np.argmax(valid_accuracy)]}')
print(f'C: {c_range[np.argmax(valid_accuracy)]}')

print(f'Accuracy of Train: {train_accuracy[np.argmax(train_accuracy)]}')
# Out:
# Max Accuracy Validation: 0.3986281493206701
# C: 0.010000000000000002
# Accuracy of Train: 0.4024535021764939

# %%
estimator = [
        ('reduce_dim', NMF(n_components=10)), 
        ('log_reg', LogisticRegression(penalty='l2', C=0.01, solver='newton-cholesky'))
    ]
nmf_pipeline = Pipeline(estimator)

nmf_pipeline.fit(X_train, y_train)
nmf_pipeline.score(X_test, y_test)
# Out:
# 0.39480279646484634

# %% [markdown]
# ### NMF and TF-IDF

# %%
X_train, X_val, X_test, y_train, y_val, y_test = utils.load_transformed_data('tf_idf_three_class')

# %%
c_range = [
    (1/10)**n
    for n in np.arange(0,10,1)
]

train_accuracy = []
valid_accuracy = []

for c in c_range:
    estimator = [
        ('reduce_dim', NMF(n_components=10)), 
        ('log_reg', LogisticRegression(penalty='l2', C=c, solver='newton-cholesky', max_iter=1000))
    ]
    nmf_pipeline = Pipeline(estimator)

    nmf_pipeline.fit(X_train, y_train)
    train_accuracy.append(nmf_pipeline.score(X_train, y_train))
    valid_accuracy.append(nmf_pipeline.score(X_val, y_val))
# Out:
# /home/jng/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /home/jng/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /home/jng/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /home/jng/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /home/jng/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
# ...

# %%
plt.figure()
plt.title('Effect on Model Accuracy by Varying C')
plt.plot(c_range, train_accuracy, label='Train')
plt.plot(c_range, valid_accuracy, label='Validation')
plt.xscale('log')
plt.xlabel('log(C)')
plt.ylabel('Accuracy')
plt.axvline(x=c_range[np.argmax(valid_accuracy)], c='red', linestyle='--')
plt.ylim(0.2,1)
plt.legend()
plt.show()


print(f'Max Accuracy Validation: {valid_accuracy[np.argmax(valid_accuracy)]}')
print(f'C: {c_range[np.argmax(valid_accuracy)]}')

print(f'Accuracy of Train: {train_accuracy[np.argmax(train_accuracy)]}')
# Out:
# Max Accuracy Validation: 0.4025854108956602
# C: 1.0
# Accuracy of Train: 0.4128742909906345

# %%
estimator = [
        ('reduce_dim', NMF(n_components=10)), 
        ('log_reg', LogisticRegression(penalty='l2', C=1, solver='newton-cholesky', max_iter=1000))
    ]
nmf_pipeline = Pipeline(estimator)

nmf_pipeline.fit(X_train, y_train)
nmf_pipeline.score(X_test, y_test)
# Out:
# /home/jng/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# 0.40232159345732754

# %% [markdown]
# # NMF and SVM and TF-IDF

# %%
from sklearn.svm import SVC

# %%
X_train, X_val, X_test, y_train, y_val, y_test = utils.load_transformed_data('tf_idf_three_class')

# %%
c_range = [
    0.01, 0.1, 10, 100, 1000
]

train_accuracy = []
valid_accuracy = []

for c in c_range:
    estimator = [
        ('reduce_dim', NMF(n_components=10)), 
        ('log_reg', SVC(C=c))
    ]
    nmf_pipeline = Pipeline(estimator)

    nmf_pipeline.fit(X_train, y_train)
    train_accuracy.append(nmf_pipeline.score(X_train, y_train))
    valid_accuracy.append(nmf_pipeline.score(X_val, y_val))
# Out:
# /home/jng/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /home/jng/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /home/jng/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /home/jng/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /home/jng/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
# ...

# %%
plt.figure()
plt.title('Effect on Model Accuracy by Varying C')
plt.plot(c_range, train_accuracy, label='Train')
plt.plot(c_range, valid_accuracy, label='Validation')
plt.xscale('log')
plt.xlabel('log(C)')
plt.ylabel('Accuracy')
plt.axvline(x=c_range[np.argmax(valid_accuracy)], c='red', linestyle='--')
plt.ylim(0.2,1)
plt.legend()
plt.show()


print(f'Max Accuracy Validation: {valid_accuracy[np.argmax(valid_accuracy)]}')
print(f'C: {c_range[np.argmax(valid_accuracy)]}')

print(f'Accuracy of Train: {train_accuracy[np.argmax(valid_accuracy)]}')
# Out:
# Max Accuracy Validation: 0.41063184276480674
# C: 10
# Accuracy of Train: 0.441938178780284

# %%
estimator = [
        ('reduce_dim', NMF(n_components=10)), 
        ('log_reg', LogisticRegression(penalty='l2', C=10, solver='newton-cholesky', max_iter=1000))
    ]
nmf_pipeline = Pipeline(estimator)

nmf_pipeline.fit(X_train, y_train)
nmf_pipeline.score(X_test, y_test)
# Out:
# /home/jng/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# 0.4000791452314998
